# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
PATH = '/Users/maraeckart/dev/hslu/fs26/DSPRO/data_testing/glamos_data/massbalance_2025_r2025/'

path_01 = 'massbalance_fixdate_2025_r2025.csv'
path_02 = 'massbalance_fixdate_elevationbins_2025_r2025.csv'
path_03 = 'massbalance_observation_2025_r2025.csv'
path_04 = 'massbalance_observation_elevationbins_2025_r2025.csv'



def load_glamos(file):
    df = pd.read_csv(
        file,
        skiprows=6,
        engine="python",
        on_bad_lines="skip"
    )
    return df

df_01 = load_glamos(PATH + path_01)
df_02 = load_glamos(PATH + path_02)
df_03 = load_glamos(PATH + path_03)
df_04 = load_glamos(PATH + path_04)

df_02.head()
# Out:
#                                 glacier name  \
# 0                                        NaN
# 1                                        NaN
# 2  Glatscher da Plattas / Glatscher da Medel
# 3  Glatscher da Plattas / Glatscher da Medel
# 4  Glatscher da Plattas / Glatscher da Medel
#
#                                glacier id start date of observation  \
# 0  (according to Swiss Glacier Inventory)                date_start
# 1                                     NaN     yyyy-mm-dd (ISO 8601)
# 2                                 A14g-16                2016-10-01
# 3                                 A14g-16                2016-10-01
# 4                                 A14g-16                2016-10-01
#
#   end date of winter observation end date of observation winter mass balance  \
# 0                date_end_winter                date_end                  Bw
# 1          yyyy-mm-dd (ISO 8601)   yyyy-mm-dd (ISO 8601)             mm w.e.
# 2                     2017-04-30              2017-09-30                1116
# 3                     2017-04-30              2017-09-30                1116
# 4                     2017-04-30              2017-09-30                 863
#
#   summer mass balance annual mass balance area of elevation bin  \
# 0                  Bs                  Ba                  area
# 1             mm w.e.             mm w.e.                   km2
# 2               -4297               -3181               0.00110
# 3               -3954               -2838               0.01030
# 4               -4150               -3287               0.04310
#
#   lower elevation of bin upper elevation of bin        observer
# 0                  h_min                  h_max             NaN
# 1                 m asl.                 m asl.             NaN
# 2                   2600                   2650   GLAMOS (2025)
# 3                   2650                   2700   GLAMOS (2025)
# 4                   2700                   2750   GLAMOS (2025)

# %%
df_02.head()
# Out:
#                                 glacier name  \
# 0                                        NaN
# 1                                        NaN
# 2  Glatscher da Plattas / Glatscher da Medel
# 3  Glatscher da Plattas / Glatscher da Medel
# 4  Glatscher da Plattas / Glatscher da Medel
#
#                                glacier id start date of observation  \
# 0  (according to Swiss Glacier Inventory)                date_start
# 1                                     NaN     yyyy-mm-dd (ISO 8601)
# 2                                 A14g-16                2016-10-01
# 3                                 A14g-16                2016-10-01
# 4                                 A14g-16                2016-10-01
#
#   end date of winter observation end date of observation winter mass balance  \
# 0                date_end_winter                date_end                  Bw
# 1          yyyy-mm-dd (ISO 8601)   yyyy-mm-dd (ISO 8601)             mm w.e.
# 2                     2017-04-30              2017-09-30                1116
# 3                     2017-04-30              2017-09-30                1116
# 4                     2017-04-30              2017-09-30                 863
#
#   summer mass balance annual mass balance area of elevation bin  \
# 0                  Bs                  Ba                  area
# 1             mm w.e.             mm w.e.                   km2
# 2               -4297               -3181               0.00110
# 3               -3954               -2838               0.01030
# 4               -4150               -3287               0.04310
#
#   lower elevation of bin upper elevation of bin        observer
# 0                  h_min                  h_max             NaN
# 1                 m asl.                 m asl.             NaN
# 2                   2600                   2650   GLAMOS (2025)
# 3                   2650                   2700   GLAMOS (2025)
# 4                   2700                   2750   GLAMOS (2025)

# %%
df_03.head()
# Out:
#                                 glacier name  \
# 0                                        NaN
# 1                                        NaN
# 2  Glatscher da Plattas / Glatscher da Medel
# 3  Glatscher da Plattas / Glatscher da Medel
# 4  Glatscher da Plattas / Glatscher da Medel
#
#                                glacier id start date of observation  \
# 0  (according to Swiss Glacier Inventory)                date_start
# 1                                     NaN     yyyy-mm-dd (ISO 8601)
# 2                                 A14g-16                2016-10-01
# 3                                 A14g-16                2017-10-01
# 4                                 A14g-16                2018-10-01
#
#   end date of winter observation end date of observation winter mass balance  \
# 0                date_end_winter                date_end                  Bw
# 1          yyyy-mm-dd (ISO 8601)   yyyy-mm-dd (ISO 8601)             mm w.e.
# 2                     2017-04-30              2017-09-30                1313
# 3                     2018-04-30              2018-09-30                1913
# 4                     2019-04-30              2019-09-30                2432
#
#   summer mass balance annual mass balance equilibrium line altitude  \
# 0                  Bs                  Ba                       ELA
# 1             mm w.e.             mm w.e.                    m asl.
# 2               -2962               -1649                      3132
# 3               -3352               -1439                      3107
# 4               -3061                -629                      3067
#
#   accumulation area ratio glacier area minimum elevation of glacier  \
# 0                     AAR         area                        h_min
# 1                       %          km2                       m asl.
# 2                       1      1.15790                         2630
# 3                       2      1.15790                         2630
# 4                      11      1.15790                         2630
#
#   maximum elevation of glacier        observer
# 0                        h_max             NaN
# 1                       m asl.             NaN
# 2                         3173   GLAMOS (2025)
# 3                         3173   GLAMOS (2025)
# 4                         3173   GLAMOS (2025)

# %%
df_04.head()
# Out:
#          glacier name                              glacier id  \
# 0                 NaN  (according to Swiss Glacier Inventory)
# 1                 NaN                                     NaN
# 2  Silvrettagletscher                                 A10g-05
# 3  Silvrettagletscher                                 A10g-05
# 4  Silvrettagletscher                                 A10g-05
#
#   start date of observation end date of winter observation  \
# 0                date_start                date_end_winter
# 1     yyyy-mm-dd (ISO 8601)          yyyy-mm-dd (ISO 8601)
# 2                1914-10-01                     1915-04-30
# 3                1914-10-01                     1915-04-30
# 4                1914-10-01                     1915-04-30
#
#   end date of observation winter mass balance summer mass balance  \
# 0                date_end                  Bw                  Bs
# 1   yyyy-mm-dd (ISO 8601)             mm w.e.             mm w.e.
# 2              1915-09-30                 976               -4158
# 3              1915-09-30                1158               -3335
# 4              1915-09-30                1409               -2318
#
#   annual mass balance area of elevation bin lower elevation of bin  \
# 0                  Ba                  area                  h_min
# 1             mm w.e.                   km2                 m asl.
# 2               -3182               0.16813                   2400
# 3               -2177               0.41000                   2500
# 4                -909               0.90250                   2600
#
#   upper elevation of bin  observer
# 0                  h_max       NaN
# 1                 m asl.       NaN
# 2                   2500    2500.0
# 3                   2600    2600.0
# 4                   2700    2700.0

# %%
print(df_01.shape)
print(df_02.shape)
print(df_03.shape)
print(df_04.shape)
# Out:
# (90, 14)
# (744, 12)
# (90, 14)
# (15092, 12)

# %%
df_01 = df_01.iloc[2:].reset_index(drop=True)
df_02 = df_02.iloc[2:].reset_index(drop=True)
df_03 = df_03.iloc[2:].reset_index(drop=True)
df_04 = df_04.iloc[2:].reset_index(drop=True)

# %%
print(df_01.columns.tolist())
print(df_02.columns.tolist())
# Out:
# ['glacier name', 'glacier id', 'start date of observation', 'end date of winter observation', 'end date of observation', 'winter mass balance', 'summer mass balance', 'annual mass balance', 'equilibrium line altitude', 'accumulation area ratio', 'glacier area', 'minimum elevation of glacier', 'maximum elevation of glacier', 'observer']
# ['glacier name', 'glacier id', 'start date of observation', 'end date of winter observation', 'end date of observation', 'winter mass balance', 'summer mass balance', 'annual mass balance', 'area of elevation bin', 'lower elevation of bin', 'upper elevation of bin', 'observer']

# %%
df_03['end date of observation'] = pd.to_datetime(df_03['end date of observation'])
df_03['year'] = df_03['end date of observation'].dt.year
df_03['annual mass balance'] = pd.to_numeric(df_03['annual mass balance'])

# %%
print(df_01.dtypes)
print(df_02.dtypes)
print(df_03.dtypes)
print(df_04.dtypes)
# Out:
# glacier name                      object
# glacier id                        object
# start date of observation         object
# end date of winter observation    object
# end date of observation           object
# winter mass balance               object
# summer mass balance               object
# annual mass balance               object
# equilibrium line altitude         object
# accumulation area ratio           object
# glacier area                      object
# minimum elevation of glacier      object
# maximum elevation of glacier      object
# observer                          object
# dtype: object
# glacier name                      object
# glacier id                        object
# start date of observation         object
# end date of winter observation    object
# end date of observation           object
# winter mass balance               object
# summer mass balance               object
# annual mass balance               object
# area of elevation bin             object
# lower elevation of bin            object
# upper elevation of bin            object
# observer                          object
# dtype: object
# glacier name                              object
# glacier id                                object
# start date of observation                 object
# end date of winter observation            object
# end date of observation           datetime64[ns]
# winter mass balance                       object
# summer mass balance                       object
# annual mass balance                        int64
# equilibrium line altitude                 object
# accumulation area ratio                   object
# glacier area                              object
# minimum elevation of glacier              object
# maximum elevation of glacier              object
# observer                                  object
# year                                       int32
# dtype: object
# glacier name                       object
# glacier id                         object
# start date of observation          object
# end date of winter observation     object
# end date of observation            object
# winter mass balance                object
# summer mass balance                object
# annual mass balance                object
# area of elevation bin              object
# lower elevation of bin             object
# upper elevation of bin             object
# observer                          float64
# dtype: object

# %%
date_cols = [
    'start date of observation',
    'end date of winter observation',
    'end date of observation'
]

for df in [df_01, df_02, df_03, df_04]:
    for col in date_cols:
        df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
for df in [df_01, df_02, df_03, df_04]:
    df[df.columns.difference([
        'glacier name',
        'glacier id',
        'observer',
        'start date of observation',
        'end date of winter observation',
        'end date of observation'
    ])] = df[df.columns.difference([
        'glacier name',
        'glacier id',
        'observer',
        'start date of observation',
        'end date of winter observation',
        'end date of observation'
    ])].apply(pd.to_numeric, errors='coerce')

# %%
df_03.info()
df_03.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   glacier name                    88 non-null     object
#  1   glacier id                      88 non-null     object
#  2   start date of observation       88 non-null     datetime64[ns]
#  3   end date of winter observation  88 non-null     datetime64[ns]
#  4   end date of observation         88 non-null     datetime64[ns]
#  5   winter mass balance             88 non-null     int64
#  6   summer mass balance             88 non-null     int64
#  7   annual mass balance             88 non-null     int64
#  8   equilibrium line altitude       88 non-null     int64
#  9   accumulation area ratio         88 non-null     int64
#  10  glacier area                    88 non-null     float64
#  11  minimum elevation of glacier    88 non-null     int64
#  12  maximum elevation of glacier    88 non-null     int64
#  13  observer                        88 non-null     object
#  14  year                            88 non-null     int32
# dtypes: datetime64[ns](3), float64(1), int32(1), int64(7), object(3)
# memory usage: 10.1+ KB
#       start date of observation end date of winter observation  \
# count                        88                             88
# mean        2019-12-17 21:00:00  2020-07-16 18:49:05.454545408
# min         2009-10-31 00:00:00            2010-04-07 00:00:00
# 25%         2017-10-01 00:00:00            2018-04-30 00:00:00
# 50%         2020-09-11 00:00:00            2021-04-27 00:00:00
# 75%         2022-10-01 00:00:00            2023-04-30 00:00:00
# max         2024-11-10 00:00:00            2025-06-29 00:00:00
# std                         NaN                            NaN
#
#              end date of observation  winter mass balance  \
# count                             88            88.000000
# mean   2020-12-15 02:10:54.545454592          1336.715909
# min              2010-09-21 00:00:00           430.000000
# 25%              2018-09-30 00:00:00           970.750000
# 50%              2021-09-18 00:00:00          1280.500000
# 75%              2023-09-30 00:00:00          1643.750000
# max              2025-09-27 00:00:00          2891.000000
# std                              NaN           491.465062
#
#        summer mass balance  annual mass balance  equilibrium line altitude  \
# count            88.000000             88.00000                  88.000000
# mean          -2789.215909          -1452.50000                3249.363636
# min           -5544.000000          -4070.00000                2795.000000
# 25%           -3405.000000          -2046.25000                3071.250000
# 50%           -2714.000000          -1378.50000                3137.500000
# 75%           -1998.750000           -643.75000                3389.750000
# max            -716.000000            -69.00000                3943.000000
# std            1033.165968            944.21419                 298.816446
#
#        accumulation area ratio  glacier area  minimum elevation of glacier  \
# count                88.000000      88.00000                     88.000000
# mean                 12.636364       1.98363                   2788.352273
# min                   0.000000       0.06810                   2321.000000
# 25%                   0.000000       0.20460                   2530.000000
# 50%                   6.000000       0.58950                   2715.000000
# 75%                  22.500000       2.62516                   2884.000000
# max                  55.000000      10.80520                   3686.000000
# std                  14.728331       2.66383                    397.001319
#
#        maximum elevation of glacier         year
# count                     88.000000    88.000000
# mean                    3311.750000  2020.215909
# min                     2945.000000  2010.000000
# 25%                     2982.000000  2018.000000
# 50%                     3253.000000  2021.000000
# 75%                     3501.000000  2023.000000
# max                     3899.000000  2025.000000
# std                      305.442105     3.524785

# %%
import matplotlib.pyplot as plt

plt.bar(df_03['year'], df_03['annual mass balance'])
plt.axhline(0)
plt.xlabel('Year')
plt.ylabel('Annual mass balance')
plt.show()

# %%
def plot_observations_per_glacier(df, title):
    counts = df.groupby('glacier name').size()
    
    counts.plot(kind='bar', figsize=(10,5))
    plt.ylabel('Number of observations')
    plt.title(title)
    plt.xticks(rotation=90)
    plt.show()

# %%
plot_observations_per_glacier(df_01, 'Observations per glacier (fixdate)')
plot_observations_per_glacier(df_02, 'Observations per glacier (fixdate elevation bins)')
plot_observations_per_glacier(df_03, 'Observations per glacier (observation)')
plot_observations_per_glacier(df_04, 'Observations per glacier (observation elevation bins)')

# %%
for df in [df_01, df_02, df_03, df_04]:
    df['end date of observation'] = pd.to_datetime(df['end date of observation'], errors='coerce')
    df['year'] = df['end date of observation'].dt.year

# %%
def plot_observations_per_year(df, title):

    counts = df.groupby('year').size()

    fig, ax = plt.subplots(figsize=(10,5))

    counts.plot(kind='bar', ax=ax, color="#4C72B0")

    ax.set_ylabel("Number of observations")
    ax.set_title(title)

    ax.spines[['top','right']].set_visible(False)
    ax.grid(axis='y', linestyle='--', alpha=0.4)

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
plot_observations_per_year(df_01, 'Observations per year (fixdate)')
plot_observations_per_year(df_02, 'Observations per year (fixdate elevation bins)')
plot_observations_per_year(df_03, 'Observations per year (observation)')
plot_observations_per_year(df_04, 'Observations per year (observation elevation bins)')

# %%
def plot_observations_per_decade(df, title):
    df_plot = df.copy()
    df_plot['decade'] = (df_plot['year'] // 10) * 10

    counts = df_plot.groupby('decade').size()

    fig, ax = plt.subplots(figsize=(10, 5))
    counts.plot(kind='bar', ax=ax, width=0.8)

    ax.set_title(title)
    ax.set_xlabel('Decade')
    ax.set_ylabel('Number of observations')

    ax.spines[['top', 'right']].set_visible(False)
    ax.grid(axis='y', linestyle='--', alpha=0.4)

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

plot_observations_per_decade(df_04,'Observations per Decade')

# %%
counts = df_04.groupby(['glacier name', 'year']).size().reset_index(name='observations')
counts.head()
# Out:
#      glacier name  year  observations
# 0  Adlergletscher  2006            13
# 1  Adlergletscher  2007            13
# 2  Adlergletscher  2008            13
# 3  Adlergletscher  2009            13
# 4  Adlergletscher  2010            13

# %%
glaciers = counts['glacier name'].unique()

fig, axes = plt.subplots(len(glaciers), 1, figsize=(10, 3*len(glaciers)), sharex=True)

for ax, glacier in zip(axes, glaciers):
    
    data = counts[counts['glacier name'] == glacier]
    
    ax.bar(data['year'], data['observations'])
    
    ax.set_title(glacier)
    ax.set_ylabel("Obs")
    
    ax.spines[['top','right']].set_visible(False)
    ax.grid(axis='y', linestyle='--', alpha=0.4)

axes[-1].set_xlabel("Year")

plt.tight_layout()
plt.show()

# %%
import math

n = len(glaciers)
cols = 3
rows = math.ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(12, 3*rows), sharex=True)

axes = axes.flatten()

for ax, glacier in zip(axes, glaciers):
    
    data = counts[counts['glacier name'] == glacier]
    
    ax.bar(data['year'], data['observations'])
    ax.set_title(glacier)
    
    ax.spines[['top','right']].set_visible(False)

for ax in axes[n:]:
    ax.remove()

plt.tight_layout()
plt.show()

# %%
df_01['dataset'] = 'fixdate'
df_02['dataset'] = 'fixdate_elevationbins'
df_03['dataset'] = 'observation'
df_04['dataset'] = 'observation_elevationbins'

# %%
combined = pd.concat([df_01, df_02, df_03, df_04], ignore_index=True)

# %%
count_table = (
    combined
    .groupby(['dataset', 'glacier name', 'year'])
    .size()
    .reset_index(name='observations')
)

# %%
count_per_glacier = (
    combined
    .groupby(['glacier name', 'year'])
    .size()
    .reset_index(name='observations')
)

count_per_glacier.head()
# Out:
#      glacier name  year  observations
# 0  Adlergletscher  2006            13
# 1  Adlergletscher  2007            13
# 2  Adlergletscher  2008            13
# 3  Adlergletscher  2009            13
# 4  Adlergletscher  2010            13

# %%
glaciers = count_per_glacier['glacier name'].unique()
n = len(glaciers)
cols = 3
rows = math.ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(12, 3*rows), sharex=True)

axes = axes.flatten()

for ax, glacier in zip(axes, glaciers):
    
    data = count_per_glacier[count_per_glacier['glacier name'] == glacier]
    
    ax.bar(data['year'], data['observations'])
    ax.set_title(glacier)
    
    ax.spines[['top','right']].set_visible(False)

for ax in axes[n:]:
    ax.remove()

plt.tight_layout()
plt.show()
