# %%
import sys

sys.path.append("../src")

import pandas as pd

import glamos_processing as glamos

# %%
df = glamos.extract_data()
df

# %%
df.describe()

# %%
df.duplicated().any()

# %%
df.isna().any()

# %%
df.dtypes

# %%
df.observation_start = pd.to_datetime(df.observation_start)
df.observation_end = pd.to_datetime(df.observation_end)

# %%
df.observation_start.max()

# %%
df.observation_start.min()

# %%
df.observation_end.max()

# %%
df.observation_end.min()

# %%
df.min()

# %%
df.max()

# %%
df.mass_balance_annual.hist()

# %%
df[df.mass_balance_annual > 1500]

# %%
df.observation_start >= "2000-10-01"

# %%
df = glamos.get_data(2000, 2019)

# %%
df.min()

# %%
df.max()
